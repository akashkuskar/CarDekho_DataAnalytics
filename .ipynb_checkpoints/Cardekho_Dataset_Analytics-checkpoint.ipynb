# %%
import pandas as pd

# %%
df=pd.read_csv("Cardekho_Dataset.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0       car_name    brand     model  min_cost_price  \
# 0           0    Maruti Alto   Maruti      Alto    3.570039e+05
# 1           1  Hyundai Grand  Hyundai     Grand    7.110000e+05
# 2           2    Hyundai i20  Hyundai       i20    8.540829e+05
# 3           3    Maruti Alto   Maruti      Alto    3.570039e+05
# 4           4  Ford Ecosport     Ford  Ecosport    1.014000e+06
#
#    max_cost_price  vehicle_age  km_driven seller_type fuel_type  \
# 0    4.654015e+05            9     120000  Individual    Petrol
# 1    7.480000e+05            5      20000  Individual    Petrol
# 2    1.307926e+06           11      60000  Individual    Petrol
# 3    4.654015e+05            9      37000  Individual    Petrol
# 4    1.379000e+06            6      30000      Dealer    Diesel
#
#   transmission_type  mileage  engine  max_power  seats  selling_price
# 0            Manual    19.70     796      46.30      5         120000
# ...

# %%
df.shape
# Out:
# (15411, 16)

# %%
df.describe()
# Out:
#          Unnamed: 0  min_cost_price  max_cost_price   vehicle_age  \
# count  15411.000000    1.541100e+04    1.541100e+04  15411.000000
# mean    9811.857699    5.892971e+06    1.962624e+06      6.036338
# std     5643.418542    5.669851e+07    2.889636e+06      3.013291
# min        0.000000    3.110000e+05    4.360000e+05      0.000000
# 25%     4906.500000    6.680000e+05    8.728667e+05      4.000000
# 50%     9872.000000    8.550000e+05    1.206000e+06      6.000000
# 75%    14668.500000    1.284000e+06    1.743000e+06      8.000000
# max    19543.000000    9.880000e+08    9.110000e+07     29.000000
#
#           km_driven       mileage        engine     max_power         seats  \
# count  1.541100e+04  15411.000000  15411.000000  15411.000000  15411.000000
# mean   5.561648e+04     19.701151   1486.057751    100.588254      5.325482
# std    5.161855e+04      4.171265    521.106696     42.972979      0.807628
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15411 non-null  int64
#  1   car_name           15411 non-null  object
#  2   brand              15411 non-null  object
#  3   model              15411 non-null  object
#  4   min_cost_price     15411 non-null  float64
#  5   max_cost_price     15411 non-null  float64
#  6   vehicle_age        15411 non-null  int64
#  7   km_driven          15411 non-null  int64
#  8   seller_type        15411 non-null  object
#  9   fuel_type          15411 non-null  object
#  10  transmission_type  15411 non-null  object
#  11  mileage            15411 non-null  float64
#  12  engine             15411 non-null  int64
#  13  max_power          15411 non-null  float64
#  14  seats              15411 non-null  int64
#  15  selling_price      15411 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# car_name             0
# brand                0
# model                0
# min_cost_price       0
# max_cost_price       0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
df.rename(columns={'Unnamed: 0':'Sr_no'},inplace=True)
df.head(5)
# Out:
#    Sr_no       car_name    brand     model  min_cost_price  max_cost_price  \
# 0      0    Maruti Alto   Maruti      Alto    3.570039e+05    4.654015e+05
# 1      1  Hyundai Grand  Hyundai     Grand    7.110000e+05    7.480000e+05
# 2      2    Hyundai i20  Hyundai       i20    8.540829e+05    1.307926e+06
# 3      3    Maruti Alto   Maruti      Alto    3.570039e+05    4.654015e+05
# 4      4  Ford Ecosport     Ford  Ecosport    1.014000e+06    1.379000e+06
#
#    vehicle_age  km_driven seller_type fuel_type transmission_type  mileage  \
# 0            9     120000  Individual    Petrol            Manual    19.70
# 1            5      20000  Individual    Petrol            Manual    18.90
# 2           11      60000  Individual    Petrol            Manual    17.00
# 3            9      37000  Individual    Petrol            Manual    20.92
# 4            6      30000      Dealer    Diesel            Manual    22.77
#
#    engine  max_power  seats  selling_price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr_no              15411 non-null  int64
#  1   car_name           15411 non-null  object
#  2   brand              15411 non-null  object
#  3   model              15411 non-null  object
#  4   min_cost_price     15411 non-null  float64
#  5   max_cost_price     15411 non-null  float64
#  6   vehicle_age        15411 non-null  int64
#  7   km_driven          15411 non-null  int64
#  8   seller_type        15411 non-null  object
#  9   fuel_type          15411 non-null  object
#  10  transmission_type  15411 non-null  object
#  11  mileage            15411 non-null  float64
#  12  engine             15411 non-null  int64
#  13  max_power          15411 non-null  float64
#  14  seats              15411 non-null  int64
#  15  selling_price      15411 non-null  int64
# ...

# %%
df.shape
# Out:
# (15411, 16)

# %%
df.tail(5)
# Out:
#        Sr_no         car_name     brand   model  min_cost_price  \
# 15406  19537      Hyundai i10   Hyundai     i10    6.983200e+05
# 15407  19540    Maruti Ertiga    Maruti  Ertiga    9.267760e+05
# 15408  19541      Skoda Rapid     Skoda   Rapid    8.926327e+05
# 15409  19542  Mahindra XUV500  Mahindra  XUV500    1.783000e+06
# 15410  19543       Honda City     Honda    City    1.330978e+06
#
#        max_cost_price  vehicle_age  km_driven seller_type fuel_type  \
# 15406    7.293333e+05            9      10723      Dealer    Petrol
# 15407    1.149968e+06            2      18000      Dealer    Petrol
# 15408    1.563551e+06            6      67000      Dealer    Diesel
# 15409    2.491000e+06            5    3800000      Dealer    Diesel
# 15410    1.707437e+06            2      13000      Dealer    Petrol
#
#       transmission_type  mileage  engine  max_power  seats  selling_price
# 15406            Manual    19.81    1086      68.05      5         250000
# ...

# %%
df['Car_unit']=df.groupby('car_name')['car_name'].transform('count')
df['Car_unit_model']=df.groupby('model')['model'].transform('count')

# %%
df.head(5)
# Out:
#    Sr_no       car_name    brand     model  min_cost_price  max_cost_price  \
# 0      0    Maruti Alto   Maruti      Alto    3.570039e+05    4.654015e+05
# 1      1  Hyundai Grand  Hyundai     Grand    7.110000e+05    7.480000e+05
# 2      2    Hyundai i20  Hyundai       i20    8.540829e+05    1.307926e+06
# 3      3    Maruti Alto   Maruti      Alto    3.570039e+05    4.654015e+05
# 4      4  Ford Ecosport     Ford  Ecosport    1.014000e+06    1.379000e+06
#
#    vehicle_age  km_driven seller_type fuel_type transmission_type  mileage  \
# 0            9     120000  Individual    Petrol            Manual    19.70
# 1            5      20000  Individual    Petrol            Manual    18.90
# 2           11      60000  Individual    Petrol            Manual    17.00
# 3            9      37000  Individual    Petrol            Manual    20.92
# 4            6      30000      Dealer    Diesel            Manual    22.77
#
# ...

# %%
car_four_year_old=df[df['vehicle_age']==4]

# %%
car_four_year_old
# Out:
#        Sr_no            car_name     brand        model  min_cost_price  \
# 9         12        Maruti Swift    Maruti        Swift    6.350000e+05
# 12        16         Mini Cooper      Mini       Cooper    4.238800e+06
# 30        36        Renault KWID   Renault         KWID    3.810000e+05
# 50        68  Maruti Swift Dzire    Maruti  Swift Dzire    6.757620e+05
# 54        76    Mahindra Scorpio  Mahindra      Scorpio    1.510000e+06
# ...      ...                 ...       ...          ...             ...
# 15367  19489          Tata Tiago      Tata        Tiago    5.430000e+05
# 15381  19509       Mahindra Thar  Mahindra         Thar    1.463000e+06
# 15389  19518  Maruti Swift Dzire    Maruti  Swift Dzire    6.757620e+05
# 15399  19529        Renault KWID   Renault         KWID    4.170000e+05
# 15400  19530         Maruti Alto    Maruti         Alto    3.570039e+05
#
#        max_cost_price  vehicle_age  km_driven seller_type fuel_type  \
# ...

# %%
df.value_counts(['car_name','seats'])
# Out:
# car_name            seats
# Hyundai i20         5        906
# Maruti Swift Dzire  5        890
# Maruti Swift        5        781
# Maruti Alto         5        760
# Honda City          5        756
#                             ...
# Hyundai Aura        5          1
# Rolls-Royce Ghost   4          1
# Mercedes-AMG C      5          1
# Maserati Ghibli     5          1
# Nissan Kicks        0          1
# Name: count, Length: 153, dtype: int64

# %%
df['car_name'].value_counts().tail(5)
# Out:
# car_name
# Mercedes-AMG C       1
# Tata Altroz          1
# Ferrari GTC4Lusso    1
# Hyundai Aura         1
# Force Gurkha         1
# Name: count, dtype: int64

# %%
#Best car in terms of mileage
df.value_counts(['car_name','mileage']).head(10).idxmax()
# Out:
# ('Hyundai Grand', 18.9)

# %%
# lowest mileage car
df.value_counts(['car_name','mileage']).tail(10).idxmin()
# Out:
# ('Ford Endeavour', 10.9)

# %%
# Best selling car with seating of 5 seater
df.value_counts(['car_name','seats']).head(10)
# Out:
# car_name            seats
# Hyundai i20         5        906
# Maruti Swift Dzire  5        890
# Maruti Swift        5        781
# Maruti Alto         5        760
# Honda City          5        756
# Maruti Wagon R      5        717
# Hyundai Grand       5        580
# Hyundai Verna       5        492
# Hyundai i10         5        410
# Ford Ecosport       5        374
# Name: count, dtype: int64

# %%
# Check Car count percentage with best Seating
# Mileage using pie chart

df.value_counts(['car_name','seats']).head(10).plot.pie(autopct='%2.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#Maximum mileage of car
# df.mileage.max()
df.value_counts('car_name','mileage').idxmax()
# Out:
# 'Hyundai i20'

# %%
# check Cars with Minimum Mileage
# df.mileage.min()
df.value_counts('car_name','mileage').idxmin()
# Out:
# 'Isuzu MUX'

# %%
#to check total selling unit of car in seating range
df.value_counts('seats').head(5)
# Out:
# seats
# 5    12910
# 7     1922
# 8      311
# 6      127
# 4       77
# Name: count, dtype: int64

# %%
#to check car sold according to its age
df.value_counts('vehicle_age').plot.bar()
# Out:
# <Axes: xlabel='vehicle_age'>

# %%
# Most number of units by car model
df.value_counts(['model']).head(10)
# Out:
# model
# i20            906
# Swift Dzire    890
# Swift          781
# Alto           778
# City           757
# Wagon R        717
# Grand          580
# Innova         545
# Verna          492
# i10            410
# Name: count, dtype: int64

# %%
df.value_counts('car_name').head(10)
# Out:
# car_name
# Hyundai i20           906
# Maruti Swift Dzire    890
# Maruti Swift          781
# Maruti Alto           778
# Honda City            757
# Maruti Wagon R        717
# Hyundai Grand         580
# Toyota Innova         545
# Hyundai Verna         492
# Hyundai i10           410
# Name: count, dtype: int64

# %%
df.value_counts(['model']).tail(10)
# Out:
# model
# Wrangler        2
# NX              2
# Aura            1
# Ghost           1
# Ghibli          1
# Altroz          1
# Gurkha          1
# GTC4Lusso       1
# C               1
# Quattroporte    1
# Name: count, dtype: int64

# %%
# check Cars count with Mileage
df.value_counts('mileage')
# Out:
# mileage
# 18.90    632
# 18.60    404
# 17.00    339
# 24.30    292
# 28.40    279
#         ...
# 16.40      1
# 16.12      1
# 15.92      1
# 15.68      1
# 17.74      1
# Name: count, Length: 411, dtype: int64

# %%
# Top cars with most number of units
y=df.value_counts('car_name').head(10).plot.bar(color="orange")
y.set_ylabel("Number of Cars units")
y.set_title("Top cars with most number of units ")
# Out:
# Text(0.5, 1.0, 'Top cars with most number of units ')
